# %%
def std_info(name,age):
    return f"name : {name},age:{age}"

std_info(10,"depi")
# Out:
# 'name : 10,age:depi'

# %%
def std_info(name,age):
    return f"name : {name},age:{age}"

std_info(age=10,name="depi")
# Out:
# 'name : depi,age:10'

# %%
def user_info(name="abanob",age=19):
    return f"name : {name},age:{age}"

user_info(10,"depi")
# Out:
# 'name : 10,age:depi'

# %%
def user_info(name:str, age:int) -> str:
    print(f"Name:{name}, age:{age}")

user_info("depi",10)
# Out:
# Name:depi, age:10

# %%
x=-5
y=abs(x)
print(y)
# Out:
# 5

# %%
x= round(3.2)
x
# Out:
# 3

# %%
my_tuple=(50,100,15,25,30,40)
x= max(my_tuple[2:])
x
# Out:
# 40

# %%
name="abanob"
print(name.upper())
# Out:
# ABANOB

# %%
def func(name:str,age:int):
    print(f"my name {name} ,my age {age}")

func("bob",25)
# Out:
# my name bob ,my age 25

# %%
def func(num1,num2):
    return (num1+num2)

func(10, 25)
# Out:
# 35

# %%
def func(name:str,age:int):
    print(f"my name {name} ,my age {age}")

func(age="bob",name=25)
# Out:
# my name 25 ,my age bob

# %%
def func(name="abanb",age=25):
    print(f"my name {name} ,my age {age}")

func(age=30)
# Out:
# my name abanb ,my age 30

# %%
def func(*name):
    print(name)
    print(type(name))

func("bob",25,True,False,500,"nabil")
# Out:
# ('bob', 25, True, False, 500, 'nabil')
# <class 'tuple'>

# %%
def func(**name):
    print(name['k1'])
    print(type(name))

func(k1 ="a",k2 ="b",k3 ="c")
# Out:
# a
# <class 'dict'>

# %%
func_name=lambda x:x+5

func_name(10)
# Out:
# 15

# %%
def func_1(n):
    return lambda a: a*n

func_2=func_1(2)
print(func_2(11))
# Out:
# 22
